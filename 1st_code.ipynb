# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
phi = np.arange(0,1,.2)
phi
#K = (2*(10**-10))*(2.718**(8.91*phi))
#K
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8])

# %%
plt.style.use('default')
plt.scatter(phi,K)
plt.plot(phi,K)
plt.xlabel('Porosity')
plt.ylabel('Permeability (m2)')
plt.grid()
plt.title('Permeability vs Porosity')
plt.legend()
# Out:
# No handles with labels found to put in legend.
